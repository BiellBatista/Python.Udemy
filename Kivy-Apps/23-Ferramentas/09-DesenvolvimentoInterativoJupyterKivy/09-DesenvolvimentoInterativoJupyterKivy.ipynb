# %%
#importação dos pacotes das classe
from kivy.app import App
from kivy.uix.widget import Widget
from kivy.interactive import InteractiveLauncher

#alteração da exibição
from kivy.config import Config
Config.set('graphics', 'fullscreen', '0')

#classe da nossa aplicação
class EstudoApp(App):
    def build(self):
        return Widget()

#criar instancia da EstudoApp()
e = EstudoApp()
ji = InteractiveLauncher(e)
ji.run()

from kivy.uix.button import Button
bt = Button(text="eXcript")

ji.root.add_widget(bt)

bt.text = "123"

def bt_click():
    print("exCript")

bt.on_press = bt_click
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\Gabriel Batista\.kivy\logs\kivy_18-09-07_14.txt
# [INFO   ] [Kivy        ] v1.10.1
# [INFO   ] [Python      ] v3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 11:27:44) [MSC v.1900 64 bit (AMD64)]
# [INFO   ] [Factory     ] 194 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_gif (img_pil, img_ffpyplayer ignored)
# [WARNING] [Call to deprecated function __init__ in C]\Users\Gabriel Batista\AppData\Local\conda\conda\envs\k36\lib\site-packages\kivy\interactive.py line 308.Called from <ipython-input-1-c736abbbd712> line 17 by <module>().
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.0.0 - Build 10.18.10.4276'>
# [INFO   ] [GL          ] OpenGL vendor <b'Intel'>
# [INFO   ] [GL          ] OpenGL renderer <b'Intel(R) HD Graphics 4000'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 0
# [INFO   ] [GL          ] Shading version <b'4.00 - Build 10.18.10.4276'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <16>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Leaving application in progress...
